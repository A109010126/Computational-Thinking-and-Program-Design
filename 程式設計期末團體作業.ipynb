# %% [markdown]
# <a href="https://colab.research.google.com/github/A109010126/Computational-Thinking-and-Program-Design/blob/main/%E7%A8%8B%E5%BC%8F%E8%A8%AD%E8%A8%88%E6%9C%9F%E6%9C%AB%E5%9C%98%E9%AB%94%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 
##SCENE1
print("這個月你被公司派遣到泰國出差。 ")
print("其中的某天你醒來後，察覺鏡中的自己雙頰泛紅搔癢，還發現有略微潰爛，更變成了「月球表面」。 ")
print("於是你決定去當地知名的診所——良心診所求診。")
print("來到診所門口後，你覺得大門略有些灰暗、破舊，莫名有些陰涼。你推開大門踏入。 ")
 
print("護理師穿著純白色的護士服說道： ")
print("「您好，這裡是良心診所！」 ")
name = input ("「不好意思，請問可以告訴我您的名字嗎?」 ")
print(f"「好的， {name} 是嗎?」 ")
answer = input("「請問您有事前預約看診嗎?」(請回答YES/NO) ")
 
if answer == "YES":
  print("「好的，走廊右轉有休息間。您可以隨意挑一間休息室進入，稍作等待。」 ")
 
elif answer == "NO":
  print("「看診需要事先預約喔，我們不接受現場排門診，謝謝。」 ") 
 
else: 
  print("你的回答似乎有誤,請再重新來過,謝謝。 ")
 
 
##SCENE2
print("你向護士點頭示意後，獨自走向通往休息室的長廊，燈光閃爍不定，有點詭異。 ")
print("這時你看到了三間房間，分別掛著不同顏色的門牌。一間是紅色的，一間是藍色的，還有一間是綠色的。 ")
print("「要選擇哪一間呢?:D」你在心裡想。於是你選擇... ")
choice = int(input("紅色門牌的房間[1]藍色門牌的房間[2]綠色門牌的房間[3] (請回答數字1/2/3) "))
 
if choice == 1:
  print("你打開紅色門牌的門，發現裡頭的燈光十分昏暗。映入眼簾的是一張鐵紅色的沙發，以及一旁的自助式咖啡機。 ")
  coffeeornot= input("「要不要喝杯咖啡呢?」你考慮著。(請回答YES/NO) ")
  
  if coffeeornot== "YES":  
    print("於是你走過去倒了一杯咖啡來喝，接著拿了一本雜誌坐下等待。 ")
    print("但是半杯咖啡都喝完了，雜誌也早就換過再換，卻遲遲不見有人來告知你看診。 ")
    print("就在你準備出去詢問的時候，護士不知為何滿臉慌張，像是要隱瞞什麼事情的樣子地敲門進來告訴你可以看診了。 ")
 
  elif coffeeornot== "NO":
    print("你選擇不去倒自助機的咖啡來喝，但這時護士卻拿了一杯咖啡走進來給你。 ")
    print("喝完這杯咖啡後你準備要看診了，但你總感覺自己昏昏沉沉的、不太對勁，不過你並沒有想太多。 ")  
 
  else: 
    print("你的回答似乎有誤,請再重新來過,謝謝。 ")
 
if choice ==  2:
  print("你選擇打開藍色門牌的房間。進入房間後，你發現眼前的簾子一直不停地在抖動。好奇心使你向前走去。")
  curtainornot= input("「要不要掀開簾子呢?」你想。(請回答YES/NO) ")
  
  if curtainornot == "YES":
    print("你小心的掀開簾子後，突然有一個不明物體朝你撲過來。")
    print("你被嚇得往後退了好幾步。")
    print("仔細看之後，才發現原來是一隻黑貓。")
    print("當你正想把牠抱起來時，沒想到那隻黑貓居然開口說話了! ")
    print("你因為這衝擊性的畫面，把自己嚇得暈了過去。 ")
    print("過了一段時間後，你醒來發現自己睡著了。 ")
    print("「原來剛剛的一切都只是一場夢啊。」你拍拍自己的胸口緩和情緒。這時護士提醒你看診時間到了。 ")
 
  elif curtainornot == "NO":
    print("你選擇不掀開簾子。不過這時簾子後面卻突然傳來一個陌生女人的聲音。 ") 
    print("「求求你...救救我...」她用哀怨的聲音哭著細語。")
    print("你頓時嚇到無法動彈，並因過於害怕而昏倒了。 ")
    print("過了一段時間後，你醒來發現自己睡著了。 ")
    print("「原來剛剛的一切都只是一場夢啊。」你拍拍自己的胸口緩和情緒。這時護士提醒你看診時間到了。 ")
 
  else: 
    print("你的回答似乎有誤,請再重新來過,謝謝。 ")
 
if choice == 3:
  print("你打開綠色門牌的房間後，發現桌子上有一張信用卡。 ")
  print("這時你有個大膽的想法... ")
  print("「嘿嘿...讓我來想想看要拿這張信用卡幹嘛好了><」 ")
  print("這時你腦中出現了天使與惡魔... ")
  print("天使：放回去吧，說不定失主在找這張信用卡呢。 ")
  print("惡魔：刷爆它，剛好蝦皮最近有618免運欸。 ")
  print("於是你決定... ")
  pictureornot = input("拾金不昧[1]刷爆[2](請回答數字1/2) ")
  
  if pictureornot == "1" :
    print("你打算把信用卡拿去櫃台的同時，護理師對你說:「已經準備好了，可以開始幫你看診囉。」 ")
    print("接著你對護理師說:「不好意思，我撿到一張不知道是誰的信用卡...」 ")
    print("護理師驚訝接過，並說:「這是我的，我找很久了!為了感謝你拾金不昧，你這次看診費用我幫你出!」 ")
 
  elif pictureornot == "2" :
    print("於是你不只清空自己蝦皮的購物車，也清空了露天、PChome24h等平台的購物車。 ")
    print("不僅如此，這次看診的費用你也用了這張信用卡付款。 ")
    print("「這張信用卡的主人也太有錢了吧。」你想。 ")
 
  else: 
    print("你的回答似乎有誤,請再重新來過,謝謝。 ")
 
 
##SCENE3
print("在前往診療間的路上，你隱隱約約覺得護士們向你投來的目光都有點怪異。 ")
print("又到了那條燈壞了的長廊上，你覺得有一股冷意襲來。 ")
print("你不願多想，一心只想著要看完醫生離開這裡趕緊回歸工作，於是快步走過。 ")
print("這時走廊盡頭的房間裡，一群身穿手術服的人拖著一些箱子，看上去是保溫用的。 ")
print("你好奇的目光追隨著他們的身影。 ")
print("卻意外看見他們和一名黑衣人交易，那人掏出大把現金交予穿著手術服的人。 ")
 
print("不僅如此，你還看到有一個穿著病人服、腹部沾滿鮮血的人突然從某處跑了出來，而他表情驚恐地大喊著「救命!救救我!」 ")
print("直到他被衝出來的護理師抓回去之前，走廊還迴盪著他淒厲的叫喊聲。 ")
print("「到底發生了什麼事?!這家診所也太奇怪了吧...」你越想越不對勁。 ")
print(f"這時，護理師突然叫起了你的名字。「{name} ...輪到你看診囉...」 ") 
seeadoctorornot = input("「該不該繼續看診呢?」你在心裡焦急地想。(請回答YES/NO) ")
 
if seeadoctorornot == "YES":
  print("雖然你覺得這間診所有些詭異，但不適感愈加讓你發疼，你也不願再繼續奔波。畢竟人生地不熟的，於是你選擇繼續看診。 ")
  print("你進到診療室後，到醫生面前並坐了下來。 ")
  print("醫生仔細詢問著你的症狀，並給予建議。 ")
  print("眼前的醫生給你感覺還是挺資深專業，是一位慈祥和藹的老先生。 ")
  print("於是你放下了戒備心，不再執著於剛剛發生的事情。 ")
  print("看完醫生領過收據後，你想著出去透透氣，便繞到了醫院後門抽根煙。 ")     
  print("卻不小心聽見了有人在說話的聲音。「是剛才在走廊盡頭房間看見的黑衣人!」你小聲驚呼。 ")
  print("而那名黑衣人因專注於和身旁的貨車司機聊天，所以沒注意到你的存在。但他們的對話內容讓你不寒而慄... ")
  print("貨車司機說：「都是今天到的貨啊？」 ")
  print("黑衣人戲謔地說：「都今天的，新鮮的很嘞！剛才還有個傻子想跑，哼，沒門。這都躺這裡了，跑得掉嗎他？」 ")
  print("黑衣人又說：「路上謹慎點，別又出了差錯，不然買家又找上門來哭哭啼啼的。」 ") 
  print("貨車司機說：「哼，這些人就是有錢囉。以為自己有錢就是老大啊，要求真多。」 ")
  print("你恍然大悟，腦中將剛剛所見所聞都串在一起，你發現了... ")
 
elif seeadoctorornot == "NO":
  print("你轉身想要找藉口離去，霎時眼前卻突然一黑，身體便失去重力向下倒。 ")
  print("再次醒來後，你被一束光晃得亮眼。你聽到有人在交談，卻聽不清內容。 ")
  print("你發覺自己躺在一張硬床上，覺得頭痛欲裂，並且聞到一股濃烈的血腥味。 ")
  print("天花板在顛倒旋轉，你吃力地去辨識了自己現在所處的環境。 ")   
  print("證實了你的猜想————你正躺在手術室裡。 ")
  print("這時你的腹部一陣撕痛，像被刀劃開一樣，動彈不得。 ")
  print("餘光一掃，更發現一旁的櫃子擺滿了各種浸泡在福馬林中的器官。 ")
  print("這時你隱約聽到旁邊有個男子嘲諷著說: ")
  print("「現在這個藥的劑量...有打夠吧...不要又像剛剛...割到一半醒來跑掉...腸子掉出來害我少了一筆生意呢...」")
  print("在醫生旁邊的助手附和回道: ")
  print("「您放心...我剛剛用了...雙倍的劑量...他在手術結束前...不可能...就算醒來...內臟也已經被掏空了...」 ")
  print("你趁他們交談之際，下了手術台後搶過醫生的手術刀，威脅他們不要靠近自己。 ")
  print("你才發現拿著手術刀不就是剛剛那位慈祥的章老醫生嗎？！ ")
  print("你一邊拿著手術刀，一邊捂住傷口奔出手術室，腦中飛快地回憶自己記得的一切。你突然恍然大悟，並聯想剛剛的對話與周遭的環境，你發現了... ")
 
else: 
  print("你的回答似乎有誤,請再重新來過,謝謝。 ")
 
 
##SCENE4
print("他們可能...在做非法的器官交易!!你不相信這麼荒謬的事情，居然就這樣被你遇到了。 ") 
callapolliceornot = input("「天啊...要報警嗎?!」你焦慮地想著，傷口的疼痛讓你無法集中精神。(請回答YES/NO) ")
 
if callapolliceornot == "YES":
  print("你立刻撥打了櫃台的電話報警，撥通後你和警察講述了你在診所發生所有的事情。 ")
  print("但沒想到警方卻不相信你說的話，還要你不要再打來惡作劇了。 ")
  print("「嘟...嘟...嘟...」電話被掛掉後，你頓時失去了希望。 ")
  print("你只好先躲在櫃台邊避開追趕的人，想著接下來該怎麼辦才好。")
  print("你突然想起來的路上停車場有看見人，所以你想去那裡碰碰運氣，看有沒有路人經過。 ")
    
elif callapolliceornot == "NO":
  print("「不...不行!現在只能靠自己了，誰知道報警來不來得及!」 ")
  print("沒逃離那個地方，都不算安全... ")
  print("於是你躲在櫃台邊，避開了追趕的人。 ")
  print("你瞥見大門全都是彪形大漢在守衛，但你記得來的路上停車場的人並不多。 ")
 
else: 
  print("你的回答似乎有誤,請再重新來過,謝謝。 ")
 
 
##SCENE5
print("於是乎你開始計畫要如何往停車場逃跑。 ") 
print("你發現自己現在只有兩種選擇了，走樓梯或是搭貨梯，但樓梯那有兩個守衛。 ")
print("「要選擇怎麼逃跑呢?」你考慮著。接著你決定... ")
stairsorelevator = input("跑向有兩個人守備的樓梯間[1]貨梯[2](請回答數字1/2) ")
 
if stairsorelevator == "1":
  print("你在櫃台順手拿了一把剪刀，抓準時機，衝向有兩個人守備的樓梯間，將剪刀插向其中一人。 ")
  print("你趁其不備，向樓下跑去，更與另一人在樓梯間追逐，他好幾次都差點抓到你。 ")
  print("那人四處找不到你，以為你躲去別的樓層，便使用對講機尋求支援，自己則沿路返回繼續尋人。 ")
  print("當你想再次找手機報警，才想起當剛剛在追逐戰時，手機已做為武器丟出去了。 ")
 
elif stairsorelevator == "2":
  print("因為樓梯有兩個人守備，所以你選擇搭乘貨梯前往停車場。 ")
  print("但你想起貨梯一般都是承載病床用的，比較少病患獨自搭乘。 ")
  print("不過你對這些樓層並不熟，不知到中途會出現什麼妖魔鬼怪。 ")
  print("「好理加在，哞郎。挖系正港ㄟ雜埔郎，毋驚啦。(台語)」你脫口而出。 ")
  print("由於他們的反應還沒那麼快，你很幸運地到達了地下室。 ")
  print("這時你想找手機報警卻找不到，也不知道在什麼時候便不見了... ")
 
else:
  print("你的回答似乎有誤,請再重新來過,謝謝。 ")
 
 
##SCENE6
print("於是你開始找人求救。你目光所及之處有三個人，分別是:停車場管理室裡的警衛、站在停車場出口處繳費的女子，以及走在車道上的小孩。 ") 
print("但你又想著，不知道他們可不可信，還是應該避開所有人自己想辦法呢？ ")
print("「怎麼辦...要找誰求教呢?」你猶豫著。你想了一下之後便決定... ")
peopleornot = input("向警衛求救[1]向女子求救[2]向小孩求救[3]靠自己[4] (請回答數字1/2/3/4) ")
 
if peopleornot == "1" :
  print("你覺得那個警衛看起來最可靠，於是你便找他求救。 ")
  print("接著你快步跑向他，希望他能幫忙報警。 ")
  print("他一開始佯裝要拿出手機幫你報警... ")
  print("沒想到下一秒卻轉過身用對講機告訴那些人你的位置! ")
  print("【你，逃脫失敗!!!】")
 
if peopleornot == "2" :
  print("你覺得那個女子或許不會加害於你，於是你便找她求救。 ")
  print("接著你快步跑向他，希望她能幫忙報警。 ")
  print("沒想到她把你帶到了一個陰暗的角落。要你先躲在這裡後，她則說自己先出去看看狀況。  ")
  print("過一會她回來了...但卻帶了一批人將你抓回去! ")
  print("【你，逃脫失敗!!!】 ")
 
if peopleornot == "3" :
  print("你覺得那個小孩看起來最純真善良，或許能夠幫助你，於是你便找他求救。 ")
  print("接著你快步跑向他，希望他能幫忙報警。 ")
  print("當你準備跟他說話時，沒想到他竟然開始大哭並抱住你的腿。 ")
  print("因此使那些人追你的人發現了你的存在! ")
  print("【你，逃脫失敗!!!】 ")
 
if peopleornot == "4" :
  print("你認為所有人都不能相信，於是決定不向任何人求助，覺得還是靠自己比較快。")
  print("你躲開所有人後，躲在車子後面，並緩緩朝出口前進。")
  print("最後，你看見一輛垃圾車正駛向停車場出口。")
  print("你強忍著傷口的疼痛，躲進垃圾中做為掩護、逃出停車場，終於逃到看不見他們的地方。")
  print("【恭喜逃脫成功!!!】 ")
  print("之後這件事也曝之於眾，你接受治療後拿到工傷理賠與保險金。 ")
  print("在社會輿論的指責下，良心診所也倒閉了，並被相關單位追究後續責任。 ")
  print("「泰國好可怕，還是待在台灣好。」每當想到這段經歷時，你仍心有餘悸。")
  print("「畢竟我是挖系正港ㄟ雜埔郎，毋驚啦。(台語)」你說。") 
 
else: 
  print("你的回答似乎有誤,請再重新來過,謝謝。")
# Out:
# 這個月你被公司派遣到泰國出差。
# 其中的某天你醒來後，察覺鏡中的自己雙頰泛紅搔癢，還發現有略微潰爛，更變成了「月球表面」。
# 於是你決定去當地知名的診所——良心診所求診。
# 來到診所門口後，你覺得大門略有些灰暗、破舊，莫名有些陰涼。你推開大門踏入。
# 護理師穿著純白色的護士服說道：
# 「您好，這裡是良心診所！」
# 「不好意思，請問可以告訴我您的名字嗎?」 康婕柔
# 「好的， 康婕柔 是嗎?」
# 「請問您有事前預約看診嗎?」(請回答YES/NO) YES
# 「好的，走廊右轉有休息間。您可以隨意挑一間休息室進入，稍作等待。」
# 你向護士點頭示意後，獨自走向通往休息室的長廊，燈光閃爍不定，有點詭異。
# 這時你看到了三間房間，分別掛著不同顏色的門牌。一間是紅色的，一間是藍色的，還有一間是綠色的。
# 「要選擇哪一間呢?:D」你在心裡想。於是你選擇...
# 紅色門牌的房間[1]藍色門牌的房間[2]綠色門牌的房間[3] (請回答數字1/2/3) 2
# 你選擇打開藍色門牌的房間。進入房間後，你發現眼前的簾子一直不停地在抖動。好奇心使你向前走去。
# 「要不要掀開簾子呢?」你想。(請回答YES/NO) YES
# 你小心的掀開簾子後，突然有一個不明物體朝你撲過來。
# 你被嚇得往後退了好幾步。
# 仔細看之後，才發現原來是一隻黑貓。
# 當你正想把牠抱起來時，沒想到那隻黑貓居然開口說話了!
# 你因為這衝擊性的畫面，把自己嚇得暈了過去。
# 過了一段時間後，你醒來發現自己睡著了。
# 「原來剛剛的一切都只是一場夢啊。」你拍拍自己的胸口緩和情緒。這時護士提醒你看診時間到了。
# 在前往診療間的路上，你隱隱約約覺得護士們向你投來的目光都有點怪異。
# 又到了那條燈壞了的長廊上，你覺得有一股冷意襲來。
# 你不願多想，一心只想著要看完醫生離開這裡趕緊回歸工作，於是快步走過。
# 這時走廊盡頭的房間裡，一群身穿手術服的人拖著一些箱子，看上去是保溫用的。
# 你好奇的目光追隨著他們的身影。
# 卻意外看見他們和一名黑衣人交易，那人掏出大把現金交予穿著手術服的人。
# 不僅如此，你還看到有一個穿著病人服、腹部沾滿鮮血的人突然從某處跑了出來，而他表情驚恐地大喊著「救命!救救我!」
# 直到他被衝出來的護理師抓回去之前，走廊還迴盪著他淒厲的叫喊聲。
# ...
